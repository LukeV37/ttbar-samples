# %%
import uproot
import matplotlib.pyplot as plt
import numpy as np

# %%
file = uproot.open("./refined_ZZ4nu.root:Refined_TTree")

# %%
features = file["features"].array()
trk_label = file["trk_label"].array()
jet_label = file["jet_label"].array()
trk_ID = file["trk_ID"].array()
Event_ID = file["Event_ID"].array()

# %%
jet_pt = np.array(features[:,0])/1000
jet_eta = np.array(features[:,1])
jet_phi = np.array(features[:,2])
trk_p_over_q = np.array(features[:,3])/1000
trk_eta = np.array(features[:,4])
trk_phi = np.array(features[:,5])
trk_d0 = np.array(features[:,6])
trk_d0_err = np.array(features[:,7])
trk_z0 = np.array(features[:,8])
trk_z0_err = np.array(features[:,9])
trk_nPixHits = np.array(features[:,10])
trk_nSharedPixHits = np.array(features[:,11])
trk_nSplitPixHits = np.array(features[:,12])
trk_nSCTHits = np.array(features[:,13])
trk_nSCTSharedHits = np.array(features[:,14])
trk_nIBLHits = np.array(features[:,15])
trk_nIBLSharedHits = np.array(features[:,16])
trk_nIBLSplitHits = np.array(features[:,17])
trk_nBLHits = np.array(features[:,18])

bkg_idx = np.array(np.where(trk_label == 1)).flatten()
sig_idx = np.array(np.where(trk_label == 0)).flatten()

print("Number of tracks: ", len(trk_label))
# Out:
# Number of tracks:  691221

# %%
plt.hist(jet_pt[sig_idx],bins=np.linspace(0, 400, 20),histtype=u'step',density=True)
plt.hist(jet_pt[bkg_idx],bins=np.linspace(0, 400, 20),histtype=u'step',density=True)
plt.title("jet_pt")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(jet_eta[sig_idx],bins=np.linspace(-5, 5, 20),histtype=u'step',density=True)
plt.hist(jet_eta[bkg_idx],bins=np.linspace(-5, 5, 20),histtype=u'step',density=True)
plt.title("jet_eta")
plt.legend(["sig","bkg"])
#plt.yscale('log')
plt.show()

# %%
plt.hist(jet_phi[sig_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.hist(jet_phi[bkg_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.title("jet_phi")
plt.legend(["sig","bkg"])
#plt.yscale('log')
plt.show()

# %%
plt.hist(trk_p_over_q[sig_idx],bins=np.linspace(-10, 10, 20),histtype=u'step',density=True)
plt.hist(trk_p_over_q[bkg_idx],bins=np.linspace(-10, 10, 20),histtype=u'step',density=True)
plt.title("trk p/q")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(trk_eta[sig_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.hist(trk_eta[bkg_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.title("trk_eta")
plt.legend(["sig","bkg"])
#plt.yscale('log')
plt.show()

# %%
plt.hist(trk_phi[sig_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.hist(trk_phi[bkg_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.title("trk_phi")
plt.legend(["sig","bkg"])
#plt.yscale('log')
plt.show()

# %%
plt.hist(trk_d0[sig_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.hist(trk_d0[bkg_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.title("trk_d0")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(trk_d0[sig_idx]/trk_d0_err[sig_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.hist(trk_d0[bkg_idx]/trk_d0_err[bkg_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.title("trk_d0_sig")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(trk_z0[sig_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.hist(trk_z0[bkg_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.title("trk_z0_sintheta")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(trk_z0[sig_idx]/trk_z0_err[sig_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.hist(trk_z0[bkg_idx]/trk_z0_err[bkg_idx],bins=np.linspace(-4, 4, 20),histtype=u'step',density=True)
plt.title("trk_z0_sintheta_sig")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(trk_nPixHits[sig_idx],bins=np.linspace(0, 25, 26),histtype=u'step',density=True)
plt.hist(trk_nPixHits[bkg_idx],bins=np.linspace(0, 25, 26),histtype=u'step',density=True)
plt.title("trk_nPixHits")
plt.legend(["sig","bkg"])
#plt.yscale('log')
plt.show()

# %%
plt.hist(trk_nSharedPixHits[sig_idx],bins=np.linspace(0, 5, 6),histtype=u'step',density=True)
plt.hist(trk_nSharedPixHits[bkg_idx],bins=np.linspace(0, 5, 6),histtype=u'step',density=True)
plt.title("trk_nSharedPixHits")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(trk_nSplitPixHits[sig_idx],bins=np.linspace(0, 12, 13),histtype=u'step',density=True)
plt.hist(trk_nSplitPixHits[bkg_idx],bins=np.linspace(0, 12, 13),histtype=u'step',density=True)
plt.title("trk_nSplitPixHits")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(trk_nSCTHits[sig_idx],bins=np.linspace(0, 20, 21),histtype=u'step',density=True)
plt.hist(trk_nSCTHits[bkg_idx],bins=np.linspace(0, 20, 21),histtype=u'step',density=True)
plt.title("trk_nSCTHits")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(trk_nSCTSharedHits[sig_idx],bins=np.linspace(0, 6, 7),histtype=u'step',density=True)
plt.hist(trk_nSCTSharedHits[bkg_idx],bins=np.linspace(0, 6, 7),histtype=u'step',density=True)
plt.title("trk_nSCTSharedHits")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(trk_nIBLHits[sig_idx],bins=np.linspace(0, 14, 15),histtype=u'step',density=True)
plt.hist(trk_nIBLHits[bkg_idx],bins=np.linspace(0, 14, 15),histtype=u'step',density=True)
plt.title("trk_nIBLHits")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(trk_nIBLSharedHits[sig_idx],bins=np.linspace(0, 4, 5),histtype=u'step',density=True)
plt.hist(trk_nIBLSharedHits[bkg_idx],bins=np.linspace(0, 4, 5),histtype=u'step',density=True)
plt.title("trk_nIBLSharedHits")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(trk_nIBLSplitHits[sig_idx],bins=np.linspace(0, 4, 5),histtype=u'step',density=True)
plt.hist(trk_nIBLSplitHits[bkg_idx],bins=np.linspace(0, 4, 5),histtype=u'step',density=True)
plt.title("trk_nIBLSplitHits")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()

# %%
plt.hist(trk_nBLHits[sig_idx],bins=np.linspace(0, 15, 16),histtype=u'step',density=True)
plt.hist(trk_nBLHits[bkg_idx],bins=np.linspace(0, 15, 16),histtype=u'step',density=True)
plt.title("trk_nBLHits")
plt.legend(["sig","bkg"])
plt.yscale('log')
plt.show()
